# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 2)
# ### The Final Capstone Project by Coursera/ Zara Nasir

# %% [markdown]
# ## Table of Contents
# * Introduction
# * Data
# * [Methodolog
# * [Analysis]_(#analysis)
# * [Results and Discussion]_(#results)
# * [Conclusion]_(#conclusion)

# %% [markdown]
# ## Introduction Business Problem <a
# name="introduction"></a>

# %% [markdown]
# In this project we will try to find an optimal place for the residents of **Leicester** to eat out from based on ratings and location. Specifically, this report will be targeted to residents interested in restaurants rather than fast food chains and cafés.
# Since there are lots of restaurants in Leicester, we will try to find places that have a **rating above 3 on TripAdvisor.** We are also interested in **areas near the University of Leicester as the students tend to be from out of the city and are trying to find new tastes.**
# We will use our data science powers to generate the most promising restaurants based on the criteria listed above.

# %% [markdown]
# ## Data <a name="data:></a>

# %% [markdown]
# Based on our definition of our problem, factors that will affect the optimal choice are:
# -	Ratings being above 3 on TripAdvisor
# -	Distance from the University of Leicester
#
# We decided to extract the necessary data from Google.

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# In this project, we will direct our efforts on detecting areas of Leicester that have high restaurant ratings, especially those with a **rating of 5**. We will limit our analysis to to an **area of 2.5 miles from the University**.
# In the first step, we have collected the data: *location, distance from the University (in miles) of the top restaurants within 2.5 miles from it, names of the restaurants and their ratings in different specifications such as value, food, atmosphere and service and rounded it all up under an ‘overall label.’*
#
# We will use a scatter graph to see how each restaurant holds overall.
#
# In the final step, we will focus on the most promising restaurants that meet all of our criteria.

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# The results we have obtained are shown in the table below:

# %% [markdown]
# Number | Restaurant	| Distance from the University	| Post Code	| Value	| Food	| Atmosphere	| Service	| Overall |
#
# 1	| Gray’s	| 1.3 miles	| LE11RE	| 5	| 5	| 5	| 5	| 5 |
#
# 2	| Barceloneta	| 0.5 miles	| LE21TU	| 4	| 4	| 4	| 4	| 4 |
#
# 3	| Bill’s	| 1.4 miles	| LE14AN	| 4	| 4.5	| 4.5	| 5	| 4.5 |
#
# 4	| Bistrot Pierre	| 1.2 miles	| LE15JN	| 4.5	| 4.5	| 4.5	| 5	| 4.5 |
#
# 5	| Bobby’s	| 2.3 miles	| LE45AT	| 4	| 4	| 3	| 4	| 4 |
#
# 6	| Carluccio’s	| 1.5 miles	| LE14SA	| 3.5	| 4	| 3.5	| 4	| 4 |
#
# 7	| Casa Romana	| 1.1	| miles	| LE16GD	| 4	| 4.5	| 4	| 4	| 4 |
#
# 8	| Chutney Ivy	| 1.2 miles	| LE11TR	| 3.5	| 3.5	| 3.5	| 4	| 3.5 |
#
# 9	| Cosy Club	| 1.5 miles	| LE14NN	| 3.5	| 4	| 4	| 4	| 4 |
#
# 10	| Grounded Kitchen	| 0.5 miles	| LE21TU	| 4.5	| 4.5	 | -	| 5	| 4.5 |
#
# 11	| Knight & Garter	| 1.2 miles	| LE15AW	| 4	| 4.5	| -	| 5	| 4.5 |
#
# 12	| Las Iguanas	| 1.1 miles	| LE16SL	| 4	| 4.5	| 4.5	| 5	| 4 |
#
# 13	| Lilu Fine Dining	| 1.5 miles	| LE14NN	| 4.5 | 5	| 4.5	| 5	| 5 |
#
# 14	| Middleton’s Steakhouse and Grill	| 1.2 miles	| LE15DB	| 4	| 4	| -	| 4	| 4 |
#
# 15	| Mirch Masala	| 2.4 miles	| LE45AU	| 3	| 3	| 3	| 3	| 3 |
#
# 16	| Pho	| 1.4 miles	| LE15YP	| 4	| 4.5	| -	| 5	| 4 |
#
# 17	| The Cookie	| 1.4 miles	| LE15YP	| 4	| 4	| 4	| 4	| 4 |
#
# 18	| The White Peacock	| 0.9 miles	| LE16RJ	| 4	4.5	| 4	| 5	| 4.5 |
#
# 19	| Wygston’s House Bar and Restaurant	| 1.3 miles	| LE15LD	| 3.5	| 3.5	| -	| 4	| 3.5 |
#
# 20	| Kayal	| 1.2 miles	| LE16FE	| 4.5	| 4.5	| 4.5	| 5	| 4.5 |
#
# 21	| More	| 0.8 miles	| LE20QD	| 4	| 4	| 4	| 4	| 4 |
#
# 22	| OGGI Simply Italian	| 0.8 miles	| LE21EG	| 4.5	| 4.5	| 4.5	| 5	| 4.5 |
#
# 23	| Shimla Pinks	| 0.8 miles	| LE20PE	| 4	| 4.5	| 4	| 4	| 4.5 |
#
# 24	| The Case	| 1.2 miles	| LE15AW	| 4	| 4	| 4	| 5	| 4 |
#
# 25	| The Rutland & Derby	| 1.2 miles	| LE15JN	| 4.5	|4.5	| 4.5	| 5	| 4.5 |
#
# 26	| Tinseltown	| 1.1 miles	| LE1 5TE	| 3	| 3	| 3	| 3	| 3.5 |
#
# 27	| World Peace Café	| 1.4 miles	| LE15FQ	| 4.5	| 5	| 4.5	 | 5	| 4.5 |
#
# 28	| Zizzi	| 1.1 miles	| LE16QH	| 3.5	| 4	| 3.5	| 4	| 4 |

# %% [markdown]
# ***Descriptive statistics from the table above are shown here:***

# %% [markdown]
# |Rating	|Mode	| Mean	| Median	| Range |
#
# | Value	| 4	| 4	| 4	| 2 |
#
# |Food	| 4.5	| 4.21	| 4.5	| 2 |
#
# |Atmosphere	| 4	| 4	| 4	| 2 |
#
# |Service	| 4.5	| 4	| 4.25	| 2 |

# %% [markdown]
# ***The Restaurants and their ratings***

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ***The Number of Restaurants in each distance are shown below***

# %% [markdown]
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# ## Results and Discussion <a name+"results"<>/a>

# %% [markdown]
# I believe that the restaurants all received the most for their ‘food’ rather than ‘value,’ ‘atmosphere’ and ‘service.’ This shows that most people will definitely care more about the food than any other factor, which is obvious as we are talking about factors. However, that doesn’t mean the other factors aren’t important. Food just got through with a 4.21 average in the ratings whereas the rest just missed out with an average of 4. If we round down, they all hold equal standing in the ratings.
#
# Mirch Masala has a rating of 3 therefore doesn’t meet our criteria so shouldn’t be considered whereas Grounded Kitchen, Knight & Garter, Middleton’s Steakhouse and Grill, Pho and Wygston’s Restaurant don’t have enough information to determine whether they meet our criteria.
#
# There were a lot more restaurants within 1.5 miles of the University radius than 1.5 miles+. This means that there is a lot of variety within this space. There was also a link between the two that were more than 1.5 miles, one was Mirch Masala and the other was Bobby’s restaurant. Both didn’t obtain a rating of 5, with one even having the lowest rating on the list.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# Our analysis shows that there is a great number of restaurants in Leicester (within 2.5. miles of the University) there are only 2 that actually have an overall rating of 5: Grays and Lilu Fine Dining. The purpose of this project was to identify the Berline areas close to the University with a high rating to aid the residents, namely students, of the city in narrowing down the search for the best place for an evening to eat out.
#
# Personally speaking, Gray’s may be a better option as it closer than Lilu’s but the final decision lays with the residents based on their specific characteristics of the locations, considering additional factors such as proximity to park, prices, distance from their homes and their current mood etc.
